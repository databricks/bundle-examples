# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/mybundleinworkspace.job.yml.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mybundleinworkspace import main

main.get_taxis(spark).show(10)
